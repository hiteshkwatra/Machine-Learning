# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv("titanic_train.csv")
data.head()
del data["Ticket"]
del data["Name"]
del data["Cabin"]
data.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch    Fare Embarked  Survived
# 0       2  female  29.0      1      0  26.000        S         1
# 1       3    male   NaN      0      0   8.050        S         0
# 2       2    male  39.0      0      0  26.000        S         0
# 3       3  female  29.0      0      4  21.075        S         0
# 4       3    male  25.0      0      0   7.050        S         0

# %%
def no(st):
    if(st=="S"):
        return 1
    elif (st=="Q"):
        return 2
    return 3
def fun(st):
    if(st=="male"):
        return 1
    return 0

# %%
(data["Embarked"]=="S").sum() + (data["Embarked"]=="Q").sum()+ (data["Embarked"]=="C").sum()
data["Emb"]=data["Embarked"].apply(no)
data
del data["Embarked"]

# %%
data["sex"]=data["Sex"].apply(fun)

# %%
data["sur"]= data["Survived"]
del data["Survived"]
del data["Sex"]

# %%
data
# Out:
#      Pclass    Age  SibSp  Parch      Fare  Emb  sex  sur
# 0         2  29.00      1      0   26.0000    1    0    1
# 1         3    NaN      0      0    8.0500    1    1    0
# 2         2  39.00      0      0   26.0000    1    1    0
# 3         3  29.00      0      4   21.0750    1    0    0
# 4         3  25.00      0      0    7.0500    1    1    0
# 5         3  34.50      0      0    6.4375    3    1    0
# 6         1  35.00      1      0   53.1000    1    0    1
# 7         3  23.00      0      0    7.8958    1    1    0
# 8         2    NaN      0      0   13.0000    1    1    1
# 9         3  50.00      0      0    8.0500    1    1    0
# 10        3  23.00      0      0    7.5500    1    0    1
# 11        3    NaN      0      0    7.2292    3    1    0
# 12        2  36.00      0      0   13.0000    1    1    0
# 13        3    NaN      1      0   15.5000    2    1    0
# 14        3    NaN      0      0    7.7500    2    0    1
# ...

# %%
data["Age"].fillna(data["Age"].mean(),inplace=True)
train=data.values
xtrain=train[:,0:7]
ytrain=train[:,7]

# %%
from sklearn.linear_model import LogisticRegression

# %%
print(alg.coef_,alg.intercept_)
# Out:
# [[-0.79851691 -0.02759995 -0.25732352 -0.12304613  0.00343261  0.26776613
#   -2.39935786]] [ 3.35334967]

# %%
alg.fit(xtrain,ytrain)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
data2= pd.read_csv("titanic_test.csv")

# %%
del data2["Ticket"]
del data2["Name"]
del data2["Cabin"]

# %%
(data2["Embarked"]=="S").sum() + (data2["Embarked"]=="Q").sum()+ (data2["Embarked"]=="C").sum()
data2["Emb"]=data2["Embarked"].apply(no)
data2
del data2["Embarked"]
data2["sex"]=data2["Sex"].apply(fun)
del data2["Sex"]
data2["Age"].fillna(data["Age"].mean(),inplace=True)

# %%
alg=LogisticRegression()

# %%
xtest=data2.values

# %%
y=alg.predict(xtest)
np.savetxt("LogisRegRes.csv",y,fmt="%.5f")
